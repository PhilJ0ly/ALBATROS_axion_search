# %% [markdown]
# Philippe Joly 2025-06-05
#
# # CPU and GPU XCORR Re-PFB Pipeline Output Comparison
#
# This notebook serves as the final test for the CPU and GPU Re-PFB pipeline comparing them with each other and with Mohan's original script.

# %%
import numpy as np
from matplotlib import pyplot as plt
import sys
from os import path
sys.path.append(path.expanduser('~'))

# %%
# fns = [
#     "/project/s/sievers/philj0ly/xcorr_cpu/xcorr_all_ant_4bit_1721361571_14336_64_468_6_7.npz",
#     "/project/s/sievers/philj0ly/xcorr_gpu/xcorr_all_ant_4bit_1721361571_14336_64_468_6_7_og.npz",
# ]

# fns = [
#     # "/project/s/sievers/philj0ly/xcorr_cpu/xcorr_all_ant_4bit_1721361671_14336_64_1788_47_48_og.npz",
#     "/project/s/sievers/philj0ly/xcorr_gpu/xcorr_all_ant_4bit_1721361671_14336_64_1788_47_48.npz",
# ]

fns = [
    "/scratch/philj0ly/test_09_11/all_ant_4bit_1721361671_1024_256_15_20_21.npz",
    "/scratch/philj0ly/test_09_11/all_ant_4bit_1721361671_1024_256_35_20_21.npz",
    "/scratch/philj0ly/test_09_11/all_ant_4bit_1721361671_1234_256_15_20_21.npz"

]
data = []
mask = []
missing_fraction = []
chans = []

for fn in fns:
    with np.load(fn) as f:
        data.append(f['data'])
        mask.append(f['mask'])
        missing_fraction.append(f["missing_fraction"])
        chans.append(f['chans'])

# data = np.array(data)
# mask = np.array(mask)
# missing_fraction = np.array(missing_fraction)
# chans = np.array(chans)

# %%
spectra = []
for i in range(len(fns)):
    print(data[i].shape)
    spectra.append(np.mean((data[i][0,0]+data[i][1,1]).real, axis=1))
# Out:
# (2, 2, 256, 2381)
# (2, 2, 256, 2381)
# (2, 2, 256, 2379)

# %%
diff = np.abs(spectra[0]-spectra[1]).flatten()
mag = np.mean(np.abs(spectra[0]).flatten())
print(np.mean(diff)/mag, np.std(diff))
# Out:
# 0.7425999 47.66726

# %%
lab = ["15", "35"]
t = 15
plt.figure(figsize=(15,10))
for i in range(2):
    plt.plot(np.log10(spectra[i]), label=lab[i])

plt.show()

# %%
with np.load("/project/s/sievers/mohanagr/xcorr_axion/xcorr_all_ant_4bit_1721361571_14336_64_15326_0_120.npz") as f:
    # Size Adjusted to match the test xcorr results
    channel_init = 6
    data_og = f['data'][:,:,channel_init*64:(channel_init+1)*64,:468]
    mask_og = f['mask'][:,:,channel_init*64:(channel_init+1)*64,:468]
    missing_fraction_og = f['missing_fraction'][:,:468]
    chans_og = f['chans'][channel_init*64:(channel_init+1)*64]

# %%
df_record = 125e6/2048 # (Hz) frequency range / # of channels
df = df_record/64
N = 14336
times = N/df_record*np.arange(468)

# %% [markdown]
# ##  Data Visualisation

# %%
spectra = np.ma.MaskedArray(data=data, mask=mask)
freqs = chans*df # (Hz)

spectra_og = np.ma.MaskedArray(data=data_og, mask=mask_og)
freqs_og = chans_og*df 

pu = ['cpu','gpu']

# %%
t = 203

plt.figure(figsize=(15,10))
for i in range(2):    
    plt.plot(freqs[i], np.log10(np.abs(spectra[i,0,0,:,t])), label=pu[i])


plt.plot(freqs_og, np.log10(np.abs(spectra_og[0,0,:,t])), label="Original")

plt.ylim(0,1)

plt.xlabel('Frequency (Hz)')   
plt.ylabel('Log10 Amplitude')
plt.legend()

plt.show()

# %% [markdown]
# This plot illustrates data amplitude across frequencies at particular times comparing the Orginal data from Mohan and my cpu as well as gpu implementation of xcorr re_pfb pipelines.

# %%
f = 10

plt.figure(figsize=(15,10))
for i in range(2):    
    plt.plot(times, np.log10(np.abs(spectra[i,0,0,f,:])), label=pu[i])

plt.plot(times, np.log10(np.abs(spectra_og[0,0,f,:])), label="Original")

plt.xlabel('Time (s)')   
plt.ylabel('Log10 Amplitude')
plt.legend()

plt.show()

# %% [markdown]
# This plot illustrates the data's amplitude at given frequencies across time comparing the Orginal data from Mohan and my cpu as well as gpu implementation of xcorr re_pfb pipelines.
#
# Note that, as expected the GPU and CPU implementation match exactly the results from Mohan.
